# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import bs4

driver=webdriver.Chrome(executable_path="C:\\Users\\Kashmiri\\Documents\\chromedriver_win32 (1)\\chromedriver.exe")
driver.get("https://courses.learncodeonline.in/learn")

print(driver.current_url)

source=driver.page_source
soup=bs4.BeautifulSoup(source,'html.parser')
video_title=soup.select('span.prox')


for video,value in enumerate(video_title):
    print(video+1,value.get_text())

# main_div=driver.find_elements_by_id('courseAvailList')

driver.quit()
# Out:
# https://courses.learncodeonline.in/learn
# 1 Flutter Dart Bundle
# 2 React native and Flutter Bundle
# 3 React Native Bundle - for Android and iOS apps
# 4 Android P and Java Bundle
# 5 Machine Learning Interview Preparation
# 6 Data Structure and Algorithm Interview preparation
# 7 HTML CSS Coding interview preparation
# 8 JavaScript Coding interview preparation
# 9 C Coding Interview Preparation
# 10 C++ Coding Interview Preparation
# 11 Python Coding Interview preparation
# 12 Android Technical Interview Preparation
# 13 Java Coding Interview Preparation
# 14 Full Stack web development with NodeJS and MongoDB
# 15 Full stack web development with Django
# 16 Docker basics for beginners
# 17 Python Crash Course
# 18 Mastering Data Structure and Algorithm with Python
# 19 Mastering Data Structure and Algorithm with Java
# 20 Mastering Data Structure and Algorithm with Cpp
# 21 Angular Crash Course
# 22 ReactJS Crash Course
# 23 Competitive Programming - Beginners C++ challenges
# ...
