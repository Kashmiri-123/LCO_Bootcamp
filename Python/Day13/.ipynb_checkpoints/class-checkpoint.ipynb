# %%
print("SELENIUM")--->helps in js scrapping by opening in google
# Out:
# SELENIUM

# %%
##automation##evrything here is executed in my browser not in server##chrome executes the js
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver=webdriver.Chrome(executable_path="C:\\Users\\Kashmiri\\Documents\\chromedriver_win32 (1)\\chromedriver.exe")
driver.get("https://www.google.com/")
elem=driver.find_element_by_xpath('//*[@id="tsf"]/div[2]/div[1]/div[1]/div/div[2]/input')
elem.send_keys("Flowers")
elem.send_keys(Keys.RETURN)

# %%
xpath=relative path of the html tag

# %%
##automation##evrything here is executed in my browser not in server##chrome executes the js
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver=webdriver.Chrome(executable_path="C:\\Users\\Kashmiri\\Documents\\chromedriver_win32 (1)\\chromedriver.exe")
driver.get("https://www.facebook.com/")
email=driver.find_element_by_xpath('//*[@id="email"]')
email.send_keys("kmonimahanta@gmail.com")
password=driver.find_element_by_xpath('//*[@id="pass"]')
password.send_keys("Li")
driver.find_element_by_id('u_0_2').click()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver=webdriver.Chrome(executable_path="C:\\Users\\Kashmiri\\Documents\\chromedriver_win32 (1)\\chromedriver.exe")
driver.get("http://www.samprit.in/")
elem=driver.find_element_by_xpath('//*[@id="email"]')
elem.send_keys("kmonimahanta@gmail.com")
message=driver.find_element_by_xpath('//*[@id="message"]')
message.send_keys("Hello Sir")
driver.find_element_by_id('svg-button-main').click()

# %%
##print the source of the website
driver=webdriver.Chrome(executable_path="C:\\Users\\Kashmiri\\Documents\\chromedriver_win32 (1)\\chromedriver.exe")
driver.get("https://samprit.in/")
print(driver.page_source)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver=webdriver.Chrome(executable_path="C:\\Users\\Kashmiri\\Documents\\chromedriver_win32 (1)\\chromedriver.exe")
driver.get("https://www.youtube.com/")
elem=driver.find_element_by_xpath('//*[@id="search"]')
elem.send_keys("Trending Videos")
elem.send_keys(Keys.RETURN)
print(driver.page_source)
# Out:
# <html style="font-size: 10px;font-family: Roboto, Arial, sans-serif; " lang="en-US"><head><script data-original-src="/yts/jsbin/player_ias-vfl7lL1_p/en_US/miniplayer.js" src="/yts/jsbin/player_ias-vfl7lL1_p/en_US/miniplayer.js"></script><script data-original-src="/yts/jsbin/player_ias-vfl7lL1_p/en_US/remote.js" src="/yts/jsbin/player_ias-vfl7lL1_p/en_US/remote.js"></script><meta http-equiv="origin-trial" data-feature="Web Components V0" data-expires="2020-10-23" content="AhbmRDASY7NuOZD9cFMgQihZ+mQpCwa8WTGdTx82vSar9ddBQbziBfZXZg+ScofvEZDdHQNCEwz4yM7HjBS9RgkAAABneyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJXZWJDb21wb25lbnRzVjAiLCJleHBpcnkiOjE2MDM0ODY4NTYsImlzU3ViZG9tYWluIjp0cnVlfQ=="><meta http-equiv="origin-trial" data-feature="Web Components V0" data-expires="2020-10-27" content="Av2+1qfUp3MwEfAFcCccykS1qFmvLiCrMZ//pHQKnRZWG9dldVo8HYuJmGj2wZ7nDg+xE4RQMQ+Ku1zKM3PvYAIAAABmeyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IldlYkNvbXBvbmVudHNWMCIsImV4cGlyeSI6
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
driver = webdriver.Chrome("C:\\Users\\Kashmiri\\Documents\\chromedriver_win32 (1)\\chromedriver.exe")
driver.get("https://www.youtube.com/feed/trending")
names=driver.find_elements_by_xpath('//*[@id="video-title"]/yt-formatted-string')
views=driver.find_elements_by_xpath('//*[@id="metadata-line"]/span[1]')
# print(views.text)
for name in names:
    for view in views:
        print(name.text)
        print(view.text)
# Out:
# Class Ki Topper Aur Last Bencher - Amit Bhadana 6.5M views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 3.5M views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 484K views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 1.6M views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 1.6M views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 3.9M views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 977K views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 28M views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 796K views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 874K views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 9.6M views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 3.1M views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 1.2M views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 1.6M views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 642K views
# Class Ki Topper Aur Last Bencher - Amit Bhadana 16M views
# ...

# %%
import requests as rq
from bs4 import BeautifulSoup
temp_data=""
res = rq.get("https://en.wikipedia.org/wiki/List_of_Marvel_Cinematic_Universe_films")                                                  
soup = BeautifulSoup(res.text, 'html.parser') 
table = soup.find("table",class_="wikitable plainrowheaders")
with open("marvel.txt","w+") as file:
    for items in table.find_all("tr")[2:]:
        data = [' '.join(item.text.split()) for item in items.find_all(['th','td'])]
        if len(data)>2:
            try:
                rating_data=rq.get("http://www.omdbapi.com/?i=tt3896198&apikey=ed593c9&t="+data[0])
                rating_data=rating_data.json()
                print(rating_data["Title"]+"    "+rating_data["Released"]+"     "+rating_data["imdbRating"])
                file.write(rating_data["Title"]+"    "+rating_data["Released"]+"     "+rating_data["imdbRating"]+"\n")
            except:
                print(data[0] ,"data not available")

# %%
spotify featured songs title and singer name
oyo-enter a location,show availabe rooms and its price and sort according to price
login to swigyy,apply swiggyeat coupon and see in which resturants it is applicable in your location
