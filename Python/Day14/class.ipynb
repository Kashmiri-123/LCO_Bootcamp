# %%
print("Key logger")
# Out:
# Key logger

# %% [markdown]
# # keyboard

# %%
from pynput import keyboard

def on_press(key):
    try:
        print('alphanumeric key {0} pressed'.format(
            key.char))
    except AttributeError:
        print('special key {0} pressed'.format(
            key))

def on_release(key):
    print('{0} released'.format(
        key))
    if key == keyboard.Key.esc:
        # Stop listener
        return False

# Collect events until released
with keyboard.Listener(
        on_press=on_press,
        on_release=on_release) as listener:
    listener.join()

# ...or, in a non-blocking fashion:
listener = keyboard.Listener(
    on_press=on_press,
    on_release=on_release)
listener.start()
# Out:
# alphanumeric key n pressed
# 'n' released
# alphanumeric key y pressed
# 'y' released
# alphanumeric key j pressed
# 'j' released
# alphanumeric key h pressed
# 'h' released
# special key Key.esc pressed
# Key.esc released
# alphanumeric key d pressed
# 'd' released
# alphanumeric key d pressed
# 'd' released
# alphanumeric key d pressed
# 'd' released
# alphanumeric key d pressed
# 'd' released
# alphanumeric key d pressed
# 'd' released
# alphanumeric key d pressed
# 'd' released
# alphanumeric key d pressed
# 'd' released
# special key Key.ctrl_l pressed
# alphanumeric key  pressed
# '\x03' released
# Key.ctrl_l released
# special key Key.ctrl_l pressed
# alphanumeric key  pressed
# '\x16' released
# Key.ctrl_l released
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# Key.ctrl_l released
# special key Key.enter pressed
# Key.enter released
# special key Key.enter pressed
# Key.enter released
# special key Key.ctrl_l pressed
# alphanumeric key  pressed
# '\x16' released
# Key.ctrl_l released
# special key Key.backspace pressed
# Key.backspace released
# alphanumeric key i pressed
# 'i' released
# special key Key.ctrl_l pressed
# alphanumeric key  pressed
# '\x03' released
# Key.ctrl_l released
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# alphanumeric key  pressed
# '\x16' released
# Key.ctrl_l released
# special key Key.right pressed
# Key.right released
# alphanumeric key ' pressed
# "'" released
# special key Key.shift_r pressed
# alphanumeric key + pressed
# '+' released
# Key.shift_r released
# alphanumeric key s pressed
# 's' released
# alphanumeric key t pressed
# alphanumeric key r pressed
# 't' released
# 'r' released
# special key Key.shift_r pressed
# alphanumeric key ( pressed
# '(' released
# Key.shift_r released
# special key Key.right pressed
# Key.right released
# special key Key.shift_r pressed
# alphanumeric key ) pressed
# ')' released
# Key.shift_r released
# alphanumeric key ' pressed
# "'" released
# special key Key.right pressed
# Key.right released
# special key Key.backspace pressed
# Key.backspace released
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# Key.ctrl_l released
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.ctrl_l pressed
# special key Key.enter pressed
# Key.enter released
# Key.ctrl_l released
# special key Key.ctrl_l pressed
# alphanumeric key  pressed
# '\x01' released
# alphanumeric key  pressed
# '\x03' released
# Key.ctrl_l released
# special key Key.ctrl_l pressed
# alphanumeric key  pressed
# Key.ctrl_l released
# 'v' released
# special key Key.enter pressed
# Key.enter released
# special key Key.shift_r pressed
# special key Key.shift_r pressed
# special key Key.shift_r pressed
# alphanumeric key + pressed
# '+' released
# Key.shift_r released
# special key Key.ctrl_l pressed
# special key Key.enter pressed
# Key.enter released
# Key.ctrl_l released
# special key Key.backspace pressed
# Key.backspace released
# special key Key.left pressed
# Key.left released
# special key Key.shift_r pressed
# alphanumeric key + pressed
# '+' released
# Key.shift_r released
# special key Key.ctrl_l pressed
# special key Key.enter pressed
# Key.enter released
# Key.ctrl_l released
# special key Key.ctrl_l pressed

# %% [markdown]
# # Mouse

# %%
from pynput import mouse
with open("mouse_mov.txt","a+") as f:
    def on_move(x, y):
        print('Pointer moved to {0}'.format(
            (x, y)))
        f.write("Pointer moved to "+str(x)+"  "+str(y))
        

    def on_click(x, y, button, pressed):
        print('{0} at {1}'.format(
            'Pressed' if pressed else 'Released',
            (x, y)))
        f.write(str(x)+" "+str(y)+'Pressed' if pressed else 'Released')
        if not pressed:
            # Stop listener
            return False

    def on_scroll(x, y, dx, dy):
        print('Scrolled {0} at {1}'.format(
            'down' if dy < 0 else 'up',
            (x, y)))
        f.write(str(x)+" "+str(y)+'Down' if dy else 'Up')

    # Collect events until released
    with mouse.Listener(
            on_move=on_move,
            on_click=on_click,
            on_scroll=on_scroll) as listener:
        listener.join()

    # ...or, in a non-blocking fashion:
    listener = mouse.Listener(
        on_move=on_move,
        on_click=on_click,
        on_scroll=on_scroll)
    listener.start()
# Out:
# Key.ctrl_r released
# Key.enter released
# Pointer moved to (549, 598)
# Pointer moved to (499, 651)
# Pointer moved to (449, 700)
# Pointer moved to (423, 726)
# Pointer moved to (405, 743)
# Pointer moved to (383, 761)
# Pointer moved to (362, 775)
# Pointer moved to (343, 787)
# Pointer moved to (323, 796)
# Pointer moved to (311, 803)
# Pointer moved to (302, 807)
# Pointer moved to (296, 810)
# Pointer moved to (292, 813)
# Pointer moved to (288, 813)
# Pointer moved to (287, 813)
# Pointer moved to (285, 813)
# Pointer moved to (284, 813)
# Pointer moved to (284, 814)
# Pointer moved to (283, 814)
# Pointer moved to (282, 814)
# Pointer moved to (281, 814)
# Pointer moved to (281, 814)
# Pointer moved to (280, 814)
# Pointer moved to (279, 814)
# Pointer moved to (279, 814)
# Pointer moved to (279, 814)
# Pointer moved to (278, 814)
# Pointer moved to (277, 814)
# Pointer moved to (277, 813)
# Pointer moved to (274, 811)
# Pointer moved to (266, 804)
# Pointer moved to (247, 786)
# Pointer moved to (213, 750)
# Pointer moved to (193, 728)
# Pointer moved to (174, 703)
# Pointer moved to (167, 691)
# Pointer moved to (161, 677)
# Pointer moved to (158, 670)
# Pointer moved to (154, 659)
# Pointer moved to (153, 656)
# Pointer moved to (151, 650)
# Pointer moved to (150, 648)
# Pointer moved to (149, 648)
# Pointer moved to (149, 646)
# Pointer moved to (148, 645)
# Pointer moved to (148, 645)
# Pointer moved to (148, 645)
# Pointer moved to (195, 604)
# Pointer moved to (234, 568)
# Pointer moved to (270, 534)
# Pointer moved to (293, 511)
# Pointer moved to (304, 500)
# Pointer moved to (313, 491)
# Pointer moved to (319, 485)
# Pointer moved to (324, 477)
# Pointer moved to (326, 475)
# Pointer moved to (327, 474)
# Pointer moved to (328, 474)
# Pointer moved to (328, 473)
# Pointer moved to (328, 473)
# Pointer moved to (328, 473)
# Pointer moved to (328, 474)
# Pointer moved to (309, 469)
# Pointer moved to (273, 461)
# Pointer moved to (230, 454)
# Pointer moved to (198, 450)
# Pointer moved to (174, 450)
# Pointer moved to (160, 449)
# Pointer moved to (152, 448)
# Pointer moved to (145, 448)
# Pointer moved to (142, 446)
# Pointer moved to (141, 445)
# Pointer moved to (140, 445)
# Pointer moved to (139, 445)
# Pointer moved to (138, 445)
# Pointer moved to (141, 421)
# Pointer moved to (146, 375)
# Pointer moved to (149, 350)
# Pointer moved to (155, 314)
# Pointer moved to (157, 292)
# Pointer moved to (160, 273)
# Pointer moved to (158, 256)
# Pointer moved to (157, 240)
# Pointer moved to (152, 226)
# Pointer moved to (151, 219)
# Pointer moved to (150, 210)
# Pointer moved to (150, 205)
# Pointer moved to (149, 196)
# Pointer moved to (148, 193)
# Pointer moved to (147, 187)
# Pointer moved to (146, 184)
# Pointer moved to (145, 182)
# Pointer moved to (144, 179)
# Pointer moved to (144, 177)
# Pointer moved to (144, 177)
# Pointer moved to (143, 176)
# Pointer moved to (143, 175)
# Pointer moved to (143, 175)
# Pointer moved to (143, 175)
# Pointer moved to (143, 174)
# Pointer moved to (143, 173)
# Pointer moved to (142, 173)
# Pointer moved to (142, 172)
# Pointer moved to (142, 172)
# Pointer moved to (142, 171)
# Pointer moved to (142, 169)
# Pointer moved to (142, 167)
# Pointer moved to (142, 163)
# Pointer moved to (143, 148)
# Pointer moved to (146, 129)
# Pointer moved to (152, 93)
# Pointer moved to (155, 76)
# Pointer moved to (156, 60)
# Pointer moved to (156, 48)
# Pointer moved to (156, 38)
# Pointer moved to (156, 34)
# Pointer moved to (156, 31)
# Pointer moved to (156, 30)
# Pointer moved to (156, 28)
# Pointer moved to (155, 27)
# Pointer moved to (155, 26)
# Pointer moved to (155, 25)
# Pointer moved to (155, 24)
# Pointer moved to (155, 23)
# Pointer moved to (155, 22)
# Pointer moved to (155, 22)
# Pointer moved to (155, 21)
# Pointer moved to (155, 20)
# Pointer moved to (155, 19)
# Pointer moved to (155, 19)
# Pointer moved to (155, 18)
# Pointer moved to (155, 17)
# Pointer moved to (155, 17)
# Pointer moved to (155, 16)
# Pointer moved to (155, 15)
# Pointer moved to (155, 14)
# Pointer moved to (155, 13)
# Pointer moved to (155, 12)
# Pointer moved to (155, 11)
# Pointer moved to (155, 10)
# Pointer moved to (155, 9)
# Pointer moved to (155, 8)
# Pointer moved to (155, 8)
# Pointer moved to (155, 7)
# Pointer moved to (155, 6)
# Pressed at (155, 6)
# Released at (155, 6)
# Unhandled exception in listener callback
# Traceback (most recent call last):
#   File "C:\Users\Kashmiri\Anaconda3\lib\site-packages\pynput\_util\win32.py", line 382, in _handler
#     converted = self._convert(code, msg, lpdata)
#   File "C:\Users\Kashmiri\Anaconda3\lib\site-packages\pynput\_util\win32.py", line 397, in _convert
#     raise NotImplementedError()
# NotImplementedError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Kashmiri\Anaconda3\lib\site-packages\pynput\_util\__init__.py", line 162, in inner
#     return f(self, *args, **kwargs)
#   File "C:\Users\Kashmiri\Anaconda3\lib\site-packages\pynput\_util\win32.py", line 386, in _handler
#     self._handle(code, msg, lpdata)
#   File "C:\Users\Kashmiri\Anaconda3\lib\site-packages\pynput\mouse\_win32.py", line 186, in _handle
#     self.on_move(data.pt.x, data.pt.y)
#   File "C:\Users\Kashmiri\Anaconda3\lib\site-packages\pynput\_util\__init__.py", line 78, in inner
#     if f(*args) is False:
#   File "<ipython-input-8-95262f53645d>", line 6, in on_move
#     f.write("Pointer moved to "+str(x)+"  "+str(y))
# ValueError: I/O operation on closed file.
# Pointer moved to (178, 26)
