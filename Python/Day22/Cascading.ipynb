# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import requests
import io


url ="https://image.shutterstock.com/image-photo/beautiful-afro-man-front-brown-260nw-620050766.jpg"
image = Image.open(io.BytesIO(requests.get(url, stream=True).content)).convert("RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=390x280 at 0x280B239A708>

# %%
image_array = np.array(image)

gray = cv2.cvtColor(image_array, cv2.COLOR_BGR2GRAY)##image array converted to 2d array
print(gray)
plt.imshow(gray)
# Out:
# [[ 54  54  54 ...  37  37  37]
#  [ 54  54  54 ...  37  37  37]
#  [ 54  54  54 ...  37  37  37]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
cv2.__path__##to check where the cv2 packages are resent
# Out:
# ['C:\\Users\\Kashmiri\\Anaconda3\\lib\\site-packages\\cv2']

# %%
detector=cv2.CascadeClassifier("C:\\Users\\Kashmiri\\Anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml")
faces = detector.detectMultiScale(gray, 1.3, 5)
print(faces)##detector gives the 4 coordinates of the face

for face in faces:
    x,y,w,h = face
    cv2.rectangle(image_array, (x,y), (x+w, y+h), (255,0,0), 5)
    
plt.imshow(image_array)
# print(image_array)
# Out:
# [[136  65 118 118]]

# %% [markdown]
# # Multiple image dectector

# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import requests
import io


multi_url ="https://curtisfamilydental.com/wp-content/uploads/2016/05/Multiple-people.jpg"
image = Image.open(io.BytesIO(requests.get(multi_url, stream=True).content)).convert("RGB")


image_array = np.array(image)

gray = cv2.cvtColor(image_array, cv2.COLOR_BGR2GRAY)
# plt.imshow(gray)

detector=cv2.CascadeClassifier("C:\\Users\\Kashmiri\\Anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml")
faces = detector.detectMultiScale(gray, 1.3, 5)

for face in faces:
    x,y,w,h = face
    cv2.rectangle(image_array, (x,y), (x+w, y+h), (255,0,0), 5)
    
plt.imshow(image_array)

# %% [markdown]
# # Video face detector

# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    _, frame = cap.read()
    
    detector=cv2.CascadeClassifier("C:\\Users\\Kashmiri\\Anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml")
    faces = detector.detectMultiScale(frame, 1.3, 5)
    
    if (len(faces)>0):
        
        for face in faces : 
            x,y,w,h = face
            cv2.rectangle(frame, (x,y), (x+w,y+h), (255,255,255),5)
            
    cv2.imshow("webcam", frame)
    
    c=cv2.waitKey(1)
    
    if c== 27:
        break
        
cap.release()
cv2.destroyAllWindows()
